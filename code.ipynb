# %%
import pandas as pd

# %%
data = pd.read_csv("mailsdata.csv")

# %%
data.sample(10)
# Out:
#       Unnamed: 0 label                                               text  \
# 2881        4068  spam  Subject: new message .\r\nyou have [ 1 ] new m...
# 1881        3985  spam  Subject: buy your medicines from us , viagra ,...
# 1200        1805   ham  Subject: duke energy deal # 387571\r\nplease v...
# 3518        3680  spam  Subject: real products for real people . b\r\n...
# 1097        4178  spam  Subject: reply : new sexy anime\r\nwould you b...
# 115         5140  spam  Subject: young pussies\r\ntonya could feel the...
# 5097         825   ham  Subject: natural gas nomination for 06 / 00\r\...
# 1465        2036   ham  Subject: tenaska gas management agreement\r\nd...
# 327         4613  spam  Subject: viicodin , via - gra are che . ap her...
# 4103        4532  spam  Subject: pain is killing you\r\nsun , 05 dec 2...
#
#       label_num
# 2881          1
# 1881          1
# 1200          0
# 3518          1
# 1097          1
# 115           1
# 5097          0
# ...

# %%
data = data[["text", "label_num"]]

# %%
data.sample(10)
# Out:
#                                                    text  label_num
# 3580  Subject: january 2001 - mcnic / lyondell noms ...          0
# 664   Subject: re : potential list fo 9 / 00\r\ncorr...          0
# 1645  Subject: popularity pills , cheap ! ! ! viagra...          1
# 92    Subject: tinydrive usb 2 . 0 mobile 2 . 2 gb s...          1
# 4593  Subject: revisions - march wellhead estimate\r...          0
# 119   Subject: nom for 2 / 17\r\nfor 2 / 17 , the no...          0
# 2074  Subject: re : gmt . inc .\r\noooops ! how abou...          0
# 3249  Subject: enron / hpl actuals for october 25 , ...          0
# 3627  Subject: re :\r\ni spoke with tufco and they a...          0
# 3972  Subject: re : chevron - winter\r\nits a monthl...          0

# %%
data["label_num"].value_counts()
# Out:
# label_num
# 0    3672
# 1    1499
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data.iloc[:1]
# Out:
#                                                 text  label_num
# 0  Subject: enron methanol ; meter # : 988291\r\n...          0

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/mahdi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
data["text"] = data["text"].apply(lambda x: word_tokenize(x))

# %%
data
# Out:
#                                                    text  label_num
# 0     [Subject, :, enron, methanol, ;, meter, #, :, ...          0
# 1     [Subject, :, hpl, nom, for, january, 9, ,, 200...          0
# 2     [Subject, :, neon, retreat, ho, ho, ho, ,, we,...          0
# 3     [Subject, :, photoshop, ,, windows, ,, office,...          1
# 4     [Subject, :, re, :, indian, springs, this, dea...          0
# ...                                                 ...        ...
# 5166  [Subject, :, put, the, 10, on, the, ft, the, t...          0
# 5167  [Subject, :, 3, /, 4, /, 2000, and, following,...          0
# 5168  [Subject, :, calpine, daily, gas, nomination, ...          0
# 5169  [Subject, :, industrial, worksheets, for, augu...          0
# 5170  [Subject, :, important, online, banking, alert...          1
#
# [5171 rows x 2 columns]

# %%
from nltk.corpus import stopwords

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /home/mahdi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("english"))

# %%
data["text"] = data["text"].apply(lambda x: [word for word in x if word not in stop_words])

# %%
data
# Out:
#                                                    text  label_num
# 0     [Subject, :, enron, methanol, ;, meter, #, :, ...          0
# 1     [Subject, :, hpl, nom, january, 9, ,, 2001, (,...          0
# 2     [Subject, :, neon, retreat, ho, ho, ho, ,, ', ...          0
# 3     [Subject, :, photoshop, ,, windows, ,, office,...          1
# 4     [Subject, :, :, indian, springs, deal, book, t...          0
# ...                                                 ...        ...
# 5166  [Subject, :, put, 10, ft, transport, volumes, ...          0
# 5167  [Subject, :, 3, /, 4, /, 2000, following, noms...          0
# 5168  [Subject, :, calpine, daily, gas, nomination, ...          0
# 5169  [Subject, :, industrial, worksheets, august, 2...          0
# 5170  [Subject, :, important, online, banking, alert...          1
#
# [5171 rows x 2 columns]

# %%
from collections import Counter

# %%
data
# Out:
#                                                    text  label_num
# 0     [Subject, :, enron, methanol, ;, meter, #, :, ...          0
# 1     [Subject, :, hpl, nom, january, 9, ,, 2001, (,...          0
# 2     [Subject, :, neon, retreat, ho, ho, ho, ,, ', ...          0
# 3     [Subject, :, photoshop, ,, windows, ,, office,...          1
# 4     [Subject, :, :, indian, springs, deal, book, t...          0
# ...                                                 ...        ...
# 5166  [Subject, :, put, 10, ft, transport, volumes, ...          0
# 5167  [Subject, :, 3, /, 4, /, 2000, following, noms...          0
# 5168  [Subject, :, calpine, daily, gas, nomination, ...          0
# 5169  [Subject, :, industrial, worksheets, august, 2...          0
# 5170  [Subject, :, important, online, banking, alert...          1
#
# [5171 rows x 2 columns]

# %%
all_words = []

# %%
for row in data["text"]:

        all_words.extend(row)

# %%
all_words
# Out:
# ['Subject',
#  ':',
#  'enron',
#  'methanol',
#  ';',
#  'meter',
#  '#',
#  ':',
#  '988291',
#  'follow',
#  'note',
#  'gave',
#  'monday',
#  ',',
#  '4',
#  '/',
#  '3',
#  '/',
#  '00',
#  '{',
#  'preliminary',
#  'flow',
#  'data',
#  'provided',
#  'daren',
#  '}',
#  '.',
#  'please',
#  'override',
#  'pop',
#  "'",
#  'daily',
#  'volume',
#  '{',
#  'presently',
#  'zero',
#  '}',
#  'reflect',
#  'daily',
#  'activity',
#  'obtain',
#  'gas',
#  'control',
#  '.',
#  'change',
#  'needed',
#  'asap',
#  'economics',
#  'purposes',
#  '.',
#  'Subject',
#  ':',
#  'hpl',
#  'nom',
#  'january',
#  '9',
#  ',',
#  '2001',
#  '(',
#  'see',
#  'attached',
#  'file',
#  ':',
#  'hplnol',
#  '09',
#  '.',
#  'xls',
#  ')',
#  '-',
#  'hplnol',
#  '09',
#  '.',
#  'xls',
#  'Subject',
#  ':',
#  'neon',
#  'retreat',
#  'ho',
#  'ho',
#  'ho',
#  ',',
#  "'",
#  'around',
#  'wonderful',
#  'time',
#  'year',
#  '-',
#  '-',
#  '-',
#  'neon',
#  'leaders',
#  'retreat',
# ...

# %%
countingOccurences = Counter(all_words)

# %%
countingOccurences
# Out:
# Counter({'-': 85723,
#          '.': 54681,
#          '/': 42848,
#          ',': 40640,
#          ':': 30275,
#          'ect': 13900,
#          '@': 12735,
#          "'": 7542,
#          'hou': 7289,
#          '?': 6875,
#          'enron': 6555,
#          ')': 6088,
#          '(': 5757,
#          '>': 5622,
#          'Subject': 5171,
#          '=': 4912,
#          ';': 4708,
#          '2000': 4386,
#          'com': 3709,
#          '!': 3636,
#          'please': 3198,
#          'gas': 3034,
#          '``': 3020,
#          '_': 3009,
#          '3': 2922,
#          '$': 2890,
#          'subject': 2889,
#          'deal': 2827,
#          '1': 2743,
#          'meter': 2459,
#          '00': 2404,
#          '#': 2385,
#          '2': 2379,
#          'cc': 2371,
#          'pm': 2343,
#          'hpl': 2318,
#          '000': 2127,
#          '10': 2113,
#          '2001': 2028,
#          'e': 1976,
#          'daren': 1901,
#          'thanks': 1898,
# ...

# %%
import string

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
type(string.punctuation)
# Out:
# str

# %%
listofpunct = []
for i in string.punctuation:
    listofpunct.append(i)

# %%
listofpunct
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
len(listofpunct)
# Out:
# 32

# %%
data["text"] = data["text"].apply(lambda x: [word for word in x if word not in listofpunct])

# %%
data["text"]
# Out:
# 0       [Subject, enron, methanol, meter, 988291, foll...
# 1       [Subject, hpl, nom, january, 9, 2001, see, att...
# 2       [Subject, neon, retreat, ho, ho, ho, around, w...
# 3       [Subject, photoshop, windows, office, cheap, m...
# 4       [Subject, indian, springs, deal, book, teco, p...
#                               ...
# 5166    [Subject, put, 10, ft, transport, volumes, dec...
# 5167    [Subject, 3, 4, 2000, following, noms, hpl, ta...
# 5168    [Subject, calpine, daily, gas, nomination, jul...
# 5169    [Subject, industrial, worksheets, august, 2000...
# 5170    [Subject, important, online, banking, alert, d...
# Name: text, Length: 5171, dtype: object

# %%
secondlistofcommon = []

for row in data["text"]:
    secondlistofcommon.extend(row)

# %%
secondlistofcommon
# Out:
# ['Subject',
#  'enron',
#  'methanol',
#  'meter',
#  '988291',
#  'follow',
#  'note',
#  'gave',
#  'monday',
#  '4',
#  '3',
#  '00',
#  'preliminary',
#  'flow',
#  'data',
#  'provided',
#  'daren',
#  'please',
#  'override',
#  'pop',
#  'daily',
#  'volume',
#  'presently',
#  'zero',
#  'reflect',
#  'daily',
#  'activity',
#  'obtain',
#  'gas',
#  'control',
#  'change',
#  'needed',
#  'asap',
#  'economics',
#  'purposes',
#  'Subject',
#  'hpl',
#  'nom',
#  'january',
#  '9',
#  '2001',
#  'see',
#  'attached',
#  'file',
#  'hplnol',
#  '09',
#  'xls',
#  'hplnol',
#  '09',
#  'xls',
#  'Subject',
#  'neon',
#  'retreat',
#  'ho',
#  'ho',
#  'ho',
#  'around',
#  'wonderful',
#  'time',
#  'year',
#  'neon',
#  'leaders',
#  'retreat',
#  'time',
#  'know',
#  'time',
#  'year',
#  'extremely',
#  'hectic',
#  'tough',
#  'think',
#  'anything',
#  'past',
#  'holidays',
#  'life',
#  'go',
#  'past',
#  'week',
#  'december',
#  '25',
#  'january',
#  '1',
# ...

# %%
tempocounter = Counter(secondlistofcommon)

# %%
tempocounter
# Out:
# Counter({'ect': 13900,
#          'hou': 7289,
#          'enron': 6555,
#          'Subject': 5171,
#          '2000': 4386,
#          'com': 3709,
#          'please': 3198,
#          'gas': 3034,
#          '``': 3020,
#          '3': 2922,
#          'subject': 2889,
#          'deal': 2827,
#          '1': 2743,
#          'meter': 2459,
#          '00': 2404,
#          '2': 2379,
#          'cc': 2371,
#          'pm': 2343,
#          'hpl': 2318,
#          '000': 2127,
#          '10': 2113,
#          '2001': 2028,
#          'e': 1976,
#          'daren': 1901,
#          'thanks': 1898,
#          '01': 1794,
#          'corp': 1776,
#          'know': 1588,
#          '0': 1586,
#          '4': 1577,
#          '5': 1565,
#          'need': 1480,
#          '11': 1440,
#          'new': 1435,
#          'may': 1381,
#          'mmbtu': 1349,
#          '12': 1345,
#          'j': 1336,
#          'forwarded': 1297,
#          'get': 1275,
#          'http': 1235,
# ...

# %%
import matplotlib.pyplot as plt

# %%
top10 = {}

# %%
type(tempocounter)
# Out:
# collections.Counter

# %%
top10 = tempocounter.most_common(10)

# %%
top10
# Out:
# [('ect', 13900),
#  ('hou', 7289),
#  ('enron', 6555),
#  ('Subject', 5171),
#  ('2000', 4386),
#  ('com', 3709),
#  ('please', 3198),
#  ('gas', 3034),
#  ('``', 3020),
#  ('3', 2922)]

# %%
plt.bar(dict(top10).keys(), dict(top10).values())
# Out:
# <BarContainer object of 10 artists>

# %%
len(top10)
# Out:
# 10

# %%
for i in range(0, 200, 10):
    plt.figure()
    top10 = tempocounter.most_common()[i:i+10]
    plt.bar(dict(top10).keys(), dict(top10).values())
    plt.show()

# %%
dictofdigits = {}
for key, value in tempocounter.items():
    if (str(key).isnumeric()):
        dictofdigits[key] = value

# %%
dictofdigits
# Out:
# {'988291': 3,
#  '4': 1577,
#  '3': 2922,
#  '00': 2404,
#  '9': 949,
#  '2001': 2028,
#  '09': 860,
#  '25': 652,
#  '1': 2743,
#  '5': 1565,
#  '6': 1043,
#  '12': 1345,
#  '13': 437,
#  '15': 782,
#  '30': 935,
#  '22': 480,
#  '21': 610,
#  '01': 1794,
#  '100': 522,
#  '2': 2379,
#  '26': 437,
#  '02': 1040,
#  '27': 451,
#  '10': 2113,
#  '33': 132,
#  '46': 95,
#  '0': 1586,
#  '456': 5,
#  '469': 1,
#  '027': 51,
#  '23': 469,
#  '2000': 4386,
#  '021': 4,
#  '025': 13,
#  '8': 894,
#  '1933': 57,
#  '1934': 48,
#  '17': 447,
#  '49000': 1,
#  '1995': 23,
#  '01405': 1,
#  '45': 300,
#  '60': 342,
#  '2004': 300,
#  '28': 501,
#  '20': 918,
#  '000': 2127,
#  '120': 184,
#  '384258': 37,
#  '902': 4,
#  '687': 2,
#  '50': 431,
#  '80': 173,
#  '14': 516,
#  '2006': 9,
#  '52': 134,
#  '81': 22,
#  '24': 568,
#  '53': 110,
#  '99': 1068,
#  '85': 127,
#  '29': 425,
#  '7': 1092,
#  '64': 32,
#  '379': 7,
#  '143': 15,
#  '886': 14,
#  '042': 2,
#  '643714': 1,
#  '04': 939,
# ...

# %%
nonspamdata = data[data["label_num"] == 0]
spamdata = data[data["label_num"] == 1]

# %%
nonspamdata
# Out:
#                                                    text  label_num
# 0     [Subject, enron, methanol, meter, 988291, foll...          0
# 1     [Subject, hpl, nom, january, 9, 2001, see, att...          0
# 2     [Subject, neon, retreat, ho, ho, ho, around, w...          0
# 4     [Subject, indian, springs, deal, book, teco, p...          0
# 5     [Subject, ehronline, web, address, change, mes...          0
# ...                                                 ...        ...
# 5165  [Subject, fw, crosstex, energy, driscoll, ranc...          0
# 5166  [Subject, put, 10, ft, transport, volumes, dec...          0
# 5167  [Subject, 3, 4, 2000, following, noms, hpl, ta...          0
# 5168  [Subject, calpine, daily, gas, nomination, jul...          0
# 5169  [Subject, industrial, worksheets, august, 2000...          0
#
# [3672 rows x 2 columns]

# %%
listofnonspam = []
listofspam = []
for row in nonspamdata["text"]:
    listofnonspam.extend(row)
for row in spamdata["text"]:
    listofspam.extend(row)

# %%
listofnonspam
# Out:
# ['Subject',
#  'enron',
#  'methanol',
#  'meter',
#  '988291',
#  'follow',
#  'note',
#  'gave',
#  'monday',
#  '4',
#  '3',
#  '00',
#  'preliminary',
#  'flow',
#  'data',
#  'provided',
#  'daren',
#  'please',
#  'override',
#  'pop',
#  'daily',
#  'volume',
#  'presently',
#  'zero',
#  'reflect',
#  'daily',
#  'activity',
#  'obtain',
#  'gas',
#  'control',
#  'change',
#  'needed',
#  'asap',
#  'economics',
#  'purposes',
#  'Subject',
#  'hpl',
#  'nom',
#  'january',
#  '9',
#  '2001',
#  'see',
#  'attached',
#  'file',
#  'hplnol',
#  '09',
#  'xls',
#  'hplnol',
#  '09',
#  'xls',
#  'Subject',
#  'neon',
#  'retreat',
#  'ho',
#  'ho',
#  'ho',
#  'around',
#  'wonderful',
#  'time',
#  'year',
#  'neon',
#  'leaders',
#  'retreat',
#  'time',
#  'know',
#  'time',
#  'year',
#  'extremely',
#  'hectic',
#  'tough',
#  'think',
#  'anything',
#  'past',
#  'holidays',
#  'life',
#  'go',
#  'past',
#  'week',
#  'december',
#  '25',
#  'january',
#  '1',
# ...

# %%
countingnonspam = Counter(listofnonspam)
countingspam = Counter(listofspam)

# %%
countingnonspam
# Out:
# Counter({'ect': 13897,
#          'hou': 7281,
#          'enron': 6555,
#          '2000': 4308,
#          'Subject': 3672,
#          'gas': 2861,
#          'deal': 2789,
#          'subject': 2731,
#          'com': 2717,
#          'please': 2715,
#          '``': 2577,
#          'meter': 2459,
#          'cc': 2359,
#          'pm': 2325,
#          'hpl': 2318,
#          '2001': 2024,
#          '1': 2023,
#          'daren': 1901,
#          '000': 1880,
#          '00': 1819,
#          '10': 1815,
#          'thanks': 1813,
#          '01': 1723,
#          'corp': 1710,
#          '3': 1683,
#          '2': 1521,
#          'know': 1438,
#          'mmbtu': 1349,
#          'e': 1338,
#          '11': 1311,
#          'j': 1300,
#          'forwarded': 1296,
#          'need': 1257,
#          '12': 1206,
#          '03': 1185,
#          'farmer': 1137,
#          'let': 1086,
#          '4': 1083,
#          'attached': 1083,
#          '5': 1055,
# ...

# %%
countingnonspam
# Out:
# Counter({'ect': 13897,
#          'hou': 7281,
#          'enron': 6555,
#          '2000': 4308,
#          'Subject': 3672,
#          'gas': 2861,
#          'deal': 2789,
#          'subject': 2731,
#          'com': 2717,
#          'please': 2715,
#          '``': 2577,
#          'meter': 2459,
#          'cc': 2359,
#          'pm': 2325,
#          'hpl': 2318,
#          '2001': 2024,
#          '1': 2023,
#          'daren': 1901,
#          '000': 1880,
#          '00': 1819,
#          '10': 1815,
#          'thanks': 1813,
#          '01': 1723,
#          'corp': 1710,
#          '3': 1683,
#          '2': 1521,
#          'know': 1438,
#          'mmbtu': 1349,
#          'e': 1338,
#          '11': 1311,
#          'j': 1300,
#          'forwarded': 1296,
#          'need': 1257,
#          '12': 1206,
#          '03': 1185,
#          'farmer': 1137,
#          'let': 1086,
#          '4': 1083,
#          'attached': 1083,
#          '5': 1055,
# ...

# %%
spamdigits = {}
nonspamdigits = {}
for key,value in dictofdigits.items():
    if (key in countingspam.keys()):
        spamdigits[key] = value
    if (key in countingnonspam.keys()):
        nonspamdigits[key] = value

# %%
spamdigits
# Out:
# {'4': 1577,
#  '3': 2922,
#  '00': 2404,
#  '9': 949,
#  '2001': 2028,
#  '09': 860,
#  '25': 652,
#  '1': 2743,
#  '5': 1565,
#  '6': 1043,
#  '12': 1345,
#  '13': 437,
#  '15': 782,
#  '30': 935,
#  '22': 480,
#  '21': 610,
#  '01': 1794,
#  '100': 522,
#  '2': 2379,
#  '26': 437,
#  '02': 1040,
#  '27': 451,
#  '10': 2113,
#  '33': 132,
#  '46': 95,
#  '0': 1586,
#  '456': 5,
#  '23': 469,
#  '2000': 4386,
#  '021': 4,
#  '025': 13,
#  '8': 894,
#  '1933': 57,
#  '1934': 48,
#  '17': 447,
#  '49000': 1,
#  '1995': 23,
#  '01405': 1,
#  '45': 300,
#  '60': 342,
#  '2004': 300,
#  '28': 501,
#  '20': 918,
#  '000': 2127,
#  '120': 184,
#  '50': 431,
#  '80': 173,
#  '14': 516,
#  '2006': 9,
#  '52': 134,
#  '81': 22,
#  '24': 568,
#  '53': 110,
#  '99': 1068,
#  '85': 127,
#  '29': 425,
#  '7': 1092,
#  '64': 32,
#  '379': 7,
#  '143': 15,
#  '886': 14,
#  '042': 2,
#  '04': 939,
#  '55': 153,
#  '800': 160,
#  '39': 137,
#  '07': 621,
#  '06': 647,
#  '400': 71,
#  '19': 448,
# ...

# %%
spamdigits
# Out:
# {'4': 1577,
#  '3': 2922,
#  '00': 2404,
#  '9': 949,
#  '2001': 2028,
#  '09': 860,
#  '25': 652,
#  '1': 2743,
#  '5': 1565,
#  '6': 1043,
#  '12': 1345,
#  '13': 437,
#  '15': 782,
#  '30': 935,
#  '22': 480,
#  '21': 610,
#  '01': 1794,
#  '100': 522,
#  '2': 2379,
#  '26': 437,
#  '02': 1040,
#  '27': 451,
#  '10': 2113,
#  '33': 132,
#  '46': 95,
#  '0': 1586,
#  '456': 5,
#  '23': 469,
#  '2000': 4386,
#  '021': 4,
#  '025': 13,
#  '8': 894,
#  '1933': 57,
#  '1934': 48,
#  '17': 447,
#  '49000': 1,
#  '1995': 23,
#  '01405': 1,
#  '45': 300,
#  '60': 342,
#  '2004': 300,
#  '28': 501,
#  '20': 918,
#  '000': 2127,
#  '120': 184,
#  '50': 431,
#  '80': 173,
#  '14': 516,
#  '2006': 9,
#  '52': 134,
#  '81': 22,
#  '24': 568,
#  '53': 110,
#  '99': 1068,
#  '85': 127,
#  '29': 425,
#  '7': 1092,
#  '64': 32,
#  '379': 7,
#  '143': 15,
#  '886': 14,
#  '042': 2,
#  '04': 939,
#  '55': 153,
#  '800': 160,
#  '39': 137,
#  '07': 621,
#  '06': 647,
#  '400': 71,
#  '19': 448,
# ...

# %%
nonspamdigits
# Out:
# {'988291': 3,
#  '4': 1577,
#  '3': 2922,
#  '00': 2404,
#  '9': 949,
#  '2001': 2028,
#  '09': 860,
#  '25': 652,
#  '1': 2743,
#  '5': 1565,
#  '6': 1043,
#  '12': 1345,
#  '13': 437,
#  '15': 782,
#  '30': 935,
#  '22': 480,
#  '21': 610,
#  '01': 1794,
#  '100': 522,
#  '2': 2379,
#  '26': 437,
#  '02': 1040,
#  '27': 451,
#  '10': 2113,
#  '33': 132,
#  '46': 95,
#  '0': 1586,
#  '456': 5,
#  '469': 1,
#  '027': 51,
#  '23': 469,
#  '2000': 4386,
#  '021': 4,
#  '025': 13,
#  '8': 894,
#  '17': 447,
#  '1995': 23,
#  '45': 300,
#  '60': 342,
#  '2004': 300,
#  '28': 501,
#  '20': 918,
#  '000': 2127,
#  '120': 184,
#  '384258': 37,
#  '902': 4,
#  '687': 2,
#  '50': 431,
#  '80': 173,
#  '14': 516,
#  '2006': 9,
#  '52': 134,
#  '81': 22,
#  '24': 568,
#  '53': 110,
#  '99': 1068,
#  '85': 127,
#  '29': 425,
#  '7': 1092,
#  '64': 32,
#  '379': 7,
#  '143': 15,
#  '886': 14,
#  '042': 2,
#  '643714': 1,
#  '04': 939,
#  '55': 153,
#  '9879': 4,
#  '800': 160,
#  '6353': 119,
# ...

# %%
max_key = max(spamdigits, key=spamdigits.get)

# %%
spamdigits[max_key]
# Out:
# 4386

# %%
max_nkey = max(nonspamdigits, key=nonspamdigits.get)

# %%
nonspamdigits[max_nkey]
# Out:
# 4386

# %%
sorted_dict_desc = dict(sorted(spamdigits.items(), key=lambda x: x[1], reverse=True))

# %%
sorted_dict_desc
# Out:
# {'2000': 4386,
#  '3': 2922,
#  '1': 2743,
#  '00': 2404,
#  '2': 2379,
#  '000': 2127,
#  '10': 2113,
#  '2001': 2028,
#  '01': 1794,
#  '0': 1586,
#  '4': 1577,
#  '5': 1565,
#  '11': 1440,
#  '12': 1345,
#  '03': 1222,
#  '7': 1092,
#  '99': 1068,
#  '6': 1043,
#  '02': 1040,
#  '9': 949,
#  '04': 939,
#  '30': 935,
#  '20': 918,
#  '8': 894,
#  '05': 884,
#  '09': 860,
#  '08': 836,
#  '15': 782,
#  '25': 652,
#  '06': 647,
#  '31': 624,
#  '07': 621,
#  '21': 610,
#  '16': 572,
#  '24': 568,
#  '713': 560,
#  '100': 522,
#  '14': 516,
#  '28': 501,
#  '22': 480,
#  '23': 469,
#  '18': 463,
#  '27': 451,
#  '19': 448,
#  '17': 447,
#  '13': 437,
#  '26': 437,
#  '50': 431,
#  '29': 425,
#  '40': 355,
#  '60': 342,
#  '45': 300,
#  '2004': 300,
#  '98': 278,
#  '500': 269,
#  '95': 222,
#  '90': 219,
#  '44': 218,
#  '69': 212,
#  '32': 195,
#  '35': 187,
#  '120': 184,
#  '1999': 174,
#  '80': 173,
#  '36': 169,
#  '63': 163,
#  '800': 160,
#  '55': 153,
#  '48': 153,
# ...

# %%
sorted_dict_desc2 = dict(sorted(nonspamdigits.items(), key=lambda x: x[1], reverse=True))

# %%
sorted_dict_desc2
# Out:
# {'2000': 4386,
#  '3': 2922,
#  '1': 2743,
#  '00': 2404,
#  '2': 2379,
#  '000': 2127,
#  '10': 2113,
#  '2001': 2028,
#  '01': 1794,
#  '0': 1586,
#  '4': 1577,
#  '5': 1565,
#  '11': 1440,
#  '12': 1345,
#  '03': 1222,
#  '7': 1092,
#  '99': 1068,
#  '6': 1043,
#  '02': 1040,
#  '9': 949,
#  '04': 939,
#  '30': 935,
#  '20': 918,
#  '8': 894,
#  '05': 884,
#  '09': 860,
#  '08': 836,
#  '15': 782,
#  '25': 652,
#  '06': 647,
#  '31': 624,
#  '07': 621,
#  '21': 610,
#  '16': 572,
#  '24': 568,
#  '713': 560,
#  '100': 522,
#  '14': 516,
#  '28': 501,
#  '22': 480,
#  '23': 469,
#  '18': 463,
#  '27': 451,
#  '19': 448,
#  '17': 447,
#  '13': 437,
#  '26': 437,
#  '50': 431,
#  '29': 425,
#  '40': 355,
#  '60': 342,
#  '45': 300,
#  '2004': 300,
#  '98': 278,
#  '500': 269,
#  '95': 222,
#  '90': 219,
#  '44': 218,
#  '69': 212,
#  '32': 195,
#  '35': 187,
#  '120': 184,
#  '1999': 174,
#  '80': 173,
#  '36': 169,
#  '63': 163,
#  '800': 160,
#  '55': 153,
#  '48': 153,
# ...

# %%
sorted_dict_desc == sorted_dict_desc2
# Out:
# False

# %%
for (key, value), (key2, value2) in zip(sorted_dict_desc.items(), sorted_dict_desc2.items()):
    if key != key2:
        print(f"{key} {value}")
        print(f"{key2} {value2}")
        break
# Out:
# 54 118
# 6353 119

# %%
data.shape
# Out:
# (5171, 2)

# %%
data["text"]
# Out:
# 0       [Subject, enron, methanol, meter, 988291, foll...
# 1       [Subject, hpl, nom, january, 9, 2001, see, att...
# 2       [Subject, neon, retreat, ho, ho, ho, around, w...
# 3       [Subject, photoshop, windows, office, cheap, m...
# 4       [Subject, indian, springs, deal, book, teco, p...
#                               ...
# 5166    [Subject, put, 10, ft, transport, volumes, dec...
# 5167    [Subject, 3, 4, 2000, following, noms, hpl, ta...
# 5168    [Subject, calpine, daily, gas, nomination, jul...
# 5169    [Subject, industrial, worksheets, august, 2000...
# 5170    [Subject, important, online, banking, alert, d...
# Name: text, Length: 5171, dtype: object

# %%
data["text"] = data["text"].apply(lambda x: [word for word in x if not word.isnumeric()])

# %%
data["text"]
# Out:
# 0       [Subject, enron, methanol, meter, follow, note...
# 1       [Subject, hpl, nom, january, see, attached, fi...
# 2       [Subject, neon, retreat, ho, ho, ho, around, w...
# 3       [Subject, photoshop, windows, office, cheap, m...
# 4       [Subject, indian, springs, deal, book, teco, p...
#                               ...
# 5166    [Subject, put, ft, transport, volumes, decreas...
# 5167    [Subject, following, noms, hpl, take, extra, m...
# 5168    [Subject, calpine, daily, gas, nomination, jul...
# 5169    [Subject, industrial, worksheets, august, acti...
# 5170    [Subject, important, online, banking, alert, d...
# Name: text, Length: 5171, dtype: object

# %%
listnondigits = []
for row in data["text"]:
    listnondigits.extend(row)

# %%
listnondigits
# Out:
# ['Subject',
#  'enron',
#  'methanol',
#  'meter',
#  'follow',
#  'note',
#  'gave',
#  'monday',
#  'preliminary',
#  'flow',
#  'data',
#  'provided',
#  'daren',
#  'please',
#  'override',
#  'pop',
#  'daily',
#  'volume',
#  'presently',
#  'zero',
#  'reflect',
#  'daily',
#  'activity',
#  'obtain',
#  'gas',
#  'control',
#  'change',
#  'needed',
#  'asap',
#  'economics',
#  'purposes',
#  'Subject',
#  'hpl',
#  'nom',
#  'january',
#  'see',
#  'attached',
#  'file',
#  'hplnol',
#  'xls',
#  'hplnol',
#  'xls',
#  'Subject',
#  'neon',
#  'retreat',
#  'ho',
#  'ho',
#  'ho',
#  'around',
#  'wonderful',
#  'time',
#  'year',
#  'neon',
#  'leaders',
#  'retreat',
#  'time',
#  'know',
#  'time',
#  'year',
#  'extremely',
#  'hectic',
#  'tough',
#  'think',
#  'anything',
#  'past',
#  'holidays',
#  'life',
#  'go',
#  'past',
#  'week',
#  'december',
#  'january',
#  'like',
#  'think',
#  'minute',
#  'calender',
#  'handed',
#  'beginning',
#  'fall',
# ...

# %%
dictnondigits = {}
dictnondigits = Counter(listnondigits)

# %%
dictnondigits
# Out:
# Counter({'ect': 13900,
#          'hou': 7289,
#          'enron': 6555,
#          'Subject': 5171,
#          'com': 3709,
#          'please': 3198,
#          'gas': 3034,
#          '``': 3020,
#          'subject': 2889,
#          'deal': 2827,
#          'meter': 2459,
#          'cc': 2371,
#          'pm': 2343,
#          'hpl': 2318,
#          'e': 1976,
#          'daren': 1901,
#          'thanks': 1898,
#          'corp': 1776,
#          'know': 1588,
#          'need': 1480,
#          'new': 1435,
#          'may': 1381,
#          'mmbtu': 1349,
#          'j': 1336,
#          'forwarded': 1297,
#          'get': 1275,
#          'http': 1235,
#          'price': 1206,
#          'see': 1200,
#          'company': 1195,
#          'let': 1159,
#          'information': 1154,
#          'farmer': 1141,
#          'l': 1108,
#          'attached': 1097,
#          'would': 1078,
#          'xls': 1020,
#          'us': 1016,
#          'day': 1007,
# ...

# %%
for i in range(0, 200, 10):
    plt.figure()
    top10 = dictnondigits.most_common()[i:i+10]
    plt.bar(dict(top10).keys(), dict(top10).values())
    plt.show()
# Out:
# /home/mahdi/Desktop/SpamMailsPrj/spamenv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 1 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
i = 0
for keys, values in dictnondigits.items():
    if values < 100:
        i = i +1

# %%
i
# Out:
# 44766

# %%
seriesnondigits = pd.Series(dictnondigits)

# %%
seriesnondigits.shape
# Out:
# (45626,)

# %%
i = 0
for keys, values in dictnondigits.items():
    if values > 100:
        i = i +1

# %%
i
# Out:
# 853

# %%
i = 0
for keys, values in dictnondigits.items():
    if values < 2:
        i = i +1

# %%
i
# Out:
# 24253

# %%
countingspam
# Out:
# Counter({'Subject': 1499,
#          '3': 1239,
#          'com': 992,
#          'http': 983,
#          '2': 858,
#          'company': 728,
#          '1': 720,
#          '0': 698,
#          'e': 638,
#          'www': 587,
#          '00': 585,
#          'information': 520,
#          'font': 515,
#          '5': 510,
#          'td': 504,
#          '4': 494,
#          'get': 485,
#          'please': 483,
#          'statements': 476,
#          'email': 474,
#          'price': 471,
#          'us': 469,
#          '7': 457,
#          '``': 443,
#          'new': 432,
#          'may': 421,
#          'nbsp': 418,
#          'one': 392,
#          'p': 391,
#          'height': 362,
#          'time': 361,
#          '8': 321,
#          '99': 321,
#          'within': 313,
#          'free': 313,
#          'pills': 311,
#          '6': 307,
#          'r': 306,
#          'size': 306,
#          'width': 306,
#          'stock': 299,
#          '2004': 299,
# ...

# %%
listofkeys = []
for key, value in dictnondigits.items():
    if value < 7:
        listofkeys.append(key)

# %%
listofkeys
# Out:
# ['override',
#  'ho',
#  'hectic',
#  'calender',
#  'handed',
#  'ministers',
#  'heartland',
#  'inn',
#  'brenham',
#  'bedroom',
#  'relaxing',
#  'antique',
#  'restaurant',
#  'dessert',
#  'recharging',
#  'democratic',
#  'prevail',
#  'preferably',
#  'complaining',
#  'tend',
#  'fishing',
#  'trending',
#  'abasements',
#  'darer',
#  'prudently',
#  'fortuitous',
#  'undergone',
#  'lighthearted',
#  'charm',
#  'orinoco',
#  'taster',
#  'affluent',
#  'pornographic',
#  'cuvier',
#  'irvin',
#  'parkhouse',
#  'blameworthy',
#  'chlorophyll',
#  'robed',
#  'diagrammatic',
#  'fogarty',
#  'clears',
#  'bayda',
#  'inconveniencing',
#  'represented',
#  'smartness',
#  'hashish',
#  'academies',
#  'unload',
#  'badness',
#  'danielson',
#  'caffein',
#  'spaniard',
#  'chargeable',
#  'levin',
#  'predermined',
#  'aka',
#  'involves',
#  'ladyfootlocker',
#  'kidsfootlocker',
#  'exclusions',
#  'redeemable',
#  'bearer',
#  'void',
#  'ruin',
#  'excuse',
# ...

# %%
i = 0
for key, value in dictnondigits.items():
    if key.isupper():
        i = i + 1

# %%
i
# Out:
# 0

# %%
data["text"] = data["text"].apply(lambda x: [word.lower() for word in x])

# %%
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
lemmatizer = WordNetLemmatizer()

# %%
data["text"] = data["text"].apply(lambda x: [ps.stem(lemmatizer.lemmatize(word)) for word in x])

# %%
finallist = []
for row in data["text"]:
    finallist.extend(row)

# %%
finallist
# Out:
# ['subject',
#  'enron',
#  'methanol',
#  'meter',
#  'follow',
#  'note',
#  'gave',
#  'monday',
#  'preliminari',
#  'flow',
#  'data',
#  'provid',
#  'daren',
#  'pleas',
#  'overrid',
#  'pop',
#  'daili',
#  'volum',
#  'present',
#  'zero',
#  'reflect',
#  'daili',
#  'activ',
#  'obtain',
#  'ga',
#  'control',
#  'chang',
#  'need',
#  'asap',
#  'econom',
#  'purpos',
#  'subject',
#  'hpl',
#  'nom',
#  'januari',
#  'see',
#  'attach',
#  'file',
#  'hplnol',
#  'xl',
#  'hplnol',
#  'xl',
#  'subject',
#  'neon',
#  'retreat',
#  'ho',
#  'ho',
#  'ho',
#  'around',
#  'wonder',
#  'time',
#  'year',
#  'neon',
#  'leader',
#  'retreat',
#  'time',
#  'know',
#  'time',
#  'year',
#  'extrem',
#  'hectic',
#  'tough',
#  'think',
#  'anyth',
#  'past',
#  'holiday',
#  'life',
#  'go',
#  'past',
#  'week',
#  'decemb',
#  'januari',
#  'like',
#  'think',
#  'minut',
#  'calend',
#  'hand',
#  'begin',
#  'fall',
#  'semest',
#  'retreat',
#  'schedul',
#  'weekend',
# ...

# %%
finaldict = {}
finaldict = Counter(finallist)

# %%
listoffigures = []
for i in range(0, 200, 10):
    fig = plt.figure()
    top10 = finaldict.most_common()[i:i+10]
    plt.bar(dict(top10).keys(), dict(top10).values())
    listoffigures.append(fig)
    plt.show()

# %%
data["text"] = data["text"].apply(lambda x: [word for word in x if len(word) > 2])

# %%
data.to_csv("postdatav1.csv", index=False)

# %%
data["text"]
# Out:
# 0       [subject, enron, methanol, meter, follow, note...
# 1       [subject, hpl, nom, januari, see, attach, file...
# 2       [subject, neon, retreat, around, wonder, time,...
# 3       [subject, photoshop, window, offic, cheap, mai...
# 4       [subject, indian, spring, deal, book, teco, pv...
#                               ...
# 5166    [subject, put, transport, volum, decreas, cont...
# 5167    [subject, follow, nom, hpl, take, extra, mmcf,...
# 5168    [subject, calpin, daili, nomin, juli, mention,...
# 5169    [subject, industri, worksheet, august, activ, ...
# 5170    [subject, import, onlin, bank, alert, dear, va...
# Name: text, Length: 5171, dtype: object

# %%
listoflowpresence = []
for key, value in finaldict.items():
    if value < 7:
        listoflowpresence.append(key)

# %%
listoflowpresence
# Out:
# ['ho',
#  'hectic',
#  'calend',
#  'heartland',
#  'inn',
#  'brenham',
#  'bedroom',
#  'antiqu',
#  'dessert',
#  'prevail',
#  'complain',
#  'tend',
#  'abas',
#  'darer',
#  'prudent',
#  'fortuit',
#  'undergon',
#  'lightheart',
#  'charm',
#  'orinoco',
#  'taster',
#  'affluent',
#  'pornograph',
#  'cuvier',
#  'irvin',
#  'parkhous',
#  'blameworthi',
#  'chlorophyl',
#  'robe',
#  'diagrammat',
#  'fogarti',
#  'bayda',
#  'inconvenienc',
#  'hashish',
#  'academi',
#  'unload',
#  'danielson',
#  'spaniard',
#  'chargeabl',
#  'levin',
#  'predermin',
#  'aka',
#  'ladyfootlock',
#  'kidsfootlock',
#  'bearer',
#  'void',
#  'ruin',
#  'simpliest',
#  'rightli',
#  'squint',
#  'splice',
#  'bombahakcx',
#  'synonym',
#  'moneyback',
#  'sufficeth',
#  'unto',
#  'hath',
#  'vocabl',
#  'ascetic',
#  'vcsc',
#  'revolution',
#  'eyefontm',
#  'softphon',
#  'itsp',
#  'revolv',
#  'converg',
#  'softswitch',
#  'quo',
#  'centuri',
#  'katonah',
#  'firstcal',
# ...

# %%
data["text"] = data["text"].apply(lambda x: [word for word in x if word not in listoflowpresence])

# %%
data["text"]
# Out:
# 0       [subject, enron, methanol, meter, follow, note...
# 1       [subject, hpl, nom, januari, see, attach, file...
# 2       [subject, neon, retreat, around, wonder, time,...
# 3       [subject, photoshop, window, offic, cheap, mai...
# 4       [subject, indian, spring, deal, book, teco, pv...
#                               ...
# 5166    [subject, put, transport, volum, decreas, cont...
# 5167    [subject, follow, nom, hpl, take, extra, mmcf,...
# 5168    [subject, calpin, daili, nomin, juli, mention,...
# 5169    [subject, industri, worksheet, august, activ, ...
# 5170    [subject, import, onlin, bank, alert, dear, va...
# Name: text, Length: 5171, dtype: object

# %%
data["text"] = data["text"].apply(lambda x: " ".join(x))

# %%
data["text"]
# Out:
# 0       subject enron methanol meter follow note gave ...
# 1       subject hpl nom januari see attach file hplnol...
# 2       subject neon retreat around wonder time year n...
# 3       subject photoshop window offic cheap main tren...
# 4       subject indian spring deal book teco pvr reven...
#                               ...
# 5166    subject put transport volum decreas contract t...
# 5167    subject follow nom hpl take extra mmcf weekend...
# 5168    subject calpin daili nomin juli mention earlie...
# 5169    subject industri worksheet august activ attach...
# 5170    subject import onlin bank alert dear valu citi...
# Name: text, Length: 5171, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(data["text"])

# %%
X
# Out:
# <5171x5466 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243736 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split

# %%
y = data["label_num"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
scores = cross_val_score(model, X_train, y_train, cv=20, scoring="accuracy", verbose=3)
# Out:
# [CV] END ................................ score: (test=0.995) total time=   0.0s
# [CV] END ................................ score: (test=0.986) total time=   0.0s
# [CV] END ................................ score: (test=0.995) total time=   0.0s
# [CV] END ................................ score: (test=0.971) total time=   0.0s
# [CV] END ................................ score: (test=0.986) total time=   0.0s
# [CV] END ................................ score: (test=0.990) total time=   0.0s
# [CV] END ................................ score: (test=0.976) total time=   0.0s
# [CV] END ................................ score: (test=0.961) total time=   0.0s
# [CV] END ................................ score: (test=0.990) total time=   0.0s
# [CV] END ................................ score: (test=0.986) total time=   0.0s
# [CV] END ................................ score: (test=0.971) total time=   0.0s
# [CV] END ................................ score: (test=0.995) total time=   0.0s
# ...

# %%
final_model = LogisticRegression()
final_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
preds = final_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_test, preds, output_dict=True)

# %%
print(report)
# Out:
# {'0': {'precision': 0.9959016393442623, 'recall': 0.9918367346938776, 'f1-score': 0.9938650306748467, 'support': 735.0}, '1': {'precision': 0.9801980198019802, 'recall': 0.99, 'f1-score': 0.9850746268656716, 'support': 300.0}, 'accuracy': 0.991304347826087, 'macro avg': {'precision': 0.9880498295731213, 'recall': 0.9909183673469388, 'f1-score': 0.9894698287702591, 'support': 1035.0}, 'weighted avg': {'precision': 0.9913498655638907, 'recall': 0.991304347826087, 'f1-score': 0.9913170875417524, 'support': 1035.0}}

# %%
def preprocess_pipeline_predict(text):
    tokens = text.lower().split() 

    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    tokens = [ps.stem(word) for word in tokens]

    processed_text = " ".join(tokens)

    transformed = vectorizer.transform([processed_text])

    prediction = final_model.predict_proba(transformed)

    return prediction

# %%
preprocess_pipeline_predict("Hi Sarah, Just a quick reminder that we have our project update meeting tomorrow at 10:00 AM in the conference room. Please bring the latest draft of your report.Let me know if you need any additional materials beforehand.Thanks,John")
# Out:
# array([[0.85974622, 0.14025378]])

# %%
import mlflow
import mlflow.sklearn

# %%
params = final_model.get_params()

# %%
listoffigures
# Out:
# [<Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>,
#  <Figure size 640x480 with 1 Axes>]

# %%
for i, figure in enumerate(listoffigures):
    print(f"Showing figure {i+1}")
    plt.figure(figure)
    plt.show()
# Out:
# Showing figure 1
# Showing figure 2
# Showing figure 3
# Showing figure 4
# Showing figure 5
# Showing figure 6
# Showing figure 7
# Showing figure 8
# Showing figure 9
# Showing figure 10
# Showing figure 11
# Showing figure 12
# Showing figure 13
# Showing figure 14
# Showing figure 15
# Showing figure 16
# Showing figure 17
# Showing figure 18
# Showing figure 19
# Showing figure 20

# %%
params
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'deprecated',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
mlflow.set_experiment("Spam Detection B-O-F TF-IDF Vectorizer")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")
with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics({
        "accuracy": report["accuracy"],
        "recall_class_non_spam": report["0"]["recall"],
        "precision_class_non_spam": report["0"]["precision"],
        "f1_score_class_non_spam": report["0"]["f1-score"],
        "recall_class_spam": report["1"]["recall"],
        "precision_class_spam": report["1"]["precision"],
        "f1_score_class_spam": report["1"]["f1-score"],
    })
    mlflow.sklearn.log_model(
        final_model,
        "model",  
        registered_model_name="Spam_Detection_Model"  
    )    

    for i, figure in enumerate(listoffigures):
        mlflow.log_figure(figure, f"most_common_features_{i+1}_{i+10}.png")
# Out:
# 2025/10/27 13:01:52 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/27 13:01:54 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'Spam_Detection_Model' already exists. Creating a new version of this model...
# 2025/10/27 13:01:55 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Spam_Detection_Model, version 5
# Created version '5' of model 'Spam_Detection_Model'.
# 🏃 View run bedecked-squid-647 at: http://127.0.0.1:5000/#/experiments/128151946307818652/runs/9664fa9e37aa4832a3be079b7d188c02
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/128151946307818652

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2 = RandomForestClassifier(random_state=42)

# %%
param_grid = {
    "n_estimators": [100, 300],       
    "max_depth": [None, 10],          
    "max_features": ["sqrt", "log2"], 
    "min_samples_split": [2, 5],
    "bootstrap": [True, False]      
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=model2,
                           param_grid=param_grid,
                           cv=5,
                           scoring="accuracy",
                           verbose=3)

# %%
#grid_search.fit(X_train, y_train)

# %%
print("Best parameters:", grid_search.best_params_)
print("Best CV score:", grid_search.best_score_)

best_model = grid_search.best_estimator_
print("Test accuracy:", best_model.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 print("Best parameters:", grid_search.best_params_)
#       2 print("Best CV score:", grid_search.best_score_)
#       4 best_model = grid_search.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
final_model2 = RandomForestClassifier(bootstrap=False, max_depth=None, max_features='log2',min_samples_split=5, n_estimators=300)

# %%
scores = cross_val_score(final_model2, X_train, y_train, cv=5, scoring="accuracy")

# %%
print(scores)
# Out:
# [0.99033816 0.97460701 0.97944377 0.96977025 0.97823458]

# %%
print(scores.mean())
# Out:
# 0.9784787573967954

# %%
final_model2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_features='log2',
#                        min_samples_split=5, n_estimators=300)

# %%
preds2 = final_model2.predict(X_test)

# %%
report2 = classification_report(y_test, preds2, output_dict=True)

# %%
print(report2)
# Out:
# {'0': {'precision': 0.9917920656634747, 'recall': 0.9863945578231292, 'f1-score': 0.9890859481582538, 'support': 735.0}, '1': {'precision': 0.9671052631578947, 'recall': 0.98, 'f1-score': 0.9735099337748344, 'support': 300.0}, 'accuracy': 0.9845410628019323, 'macro avg': {'precision': 0.9794486644106847, 'recall': 0.9831972789115646, 'f1-score': 0.9812979409665441, 'support': 1035.0}, 'weighted avg': {'precision': 0.9846364707343211, 'recall': 0.9845410628019323, 'f1-score': 0.9845711613804511, 'support': 1035.0}}

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, preds2))
# Out:
# 0.9845410628019323

# %%
params = final_model2.get_params()

# %%
params
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'log2',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 300,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
mlflow.set_experiment("Spam Detection B-O-F TF-IDF Vectorizer")

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics({
        "accuracy": report2["accuracy"],
        "recall_class_non_spam": report2["0"]["recall"],
        "precision_class_non_spam": report2["0"]["precision"],
        "f1_score_class_non_spam": report2["0"]["f1-score"],
        "recall_class_spam": report2["1"]["recall"],
        "precision_class_spam": report2["1"]["precision"],
        "f1_score_class_spam": report2["1"]["f1-score"],
    })
    mlflow.sklearn.log_model(
        final_model2,
        "model2",  
        registered_model_name="Spam_Detection_Model RF test"  
    )
# Out:
# 2025/10/27 13:03:21 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/27 13:03:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'Spam_Detection_Model RF test' already exists. Creating a new version of this model...
# 2025/10/27 13:03:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Spam_Detection_Model RF test, version 3
# Created version '3' of model 'Spam_Detection_Model RF test'.
# 🏃 View run trusting-mare-982 at: http://127.0.0.1:5000/#/experiments/128151946307818652/runs/dbec46cb80b24d389a6b58fd5252ed55
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/128151946307818652

# %%
def preprocess_pipeline_predictrf(text):
    tokens = text.lower().split() 

    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    tokens = [ps.stem(word) for word in tokens]

    processed_text = " ".join(tokens)

    transformed = vectorizer.transform([processed_text])

    prediction = final_model2.predict_proba(transformed)

    return prediction

# %%
print(preprocess_pipeline_predictrf("Hi, my name is MAhdi, I'm writing this email to officially let you know that you have accepted for an intership in regard of your curriculum, hereby please reach out, Regards, Business"))
# Out:
# [[0.63611111 0.36388889]]

# %%
from sklearn.svm import SVC

# %%
model3 = SVC(random_state=42)

# %%
param_grid3 = {
    'C': [0.1, 1, 2, 5, 10, 100],
    'kernel': ['rbf', 'linear'],
    'gamma': [0.01, 0.1, 1, 2, 10],
    'class_weight': [None, 'balanced']

}

# %%
grid_searchSVC = GridSearchCV(model3, param_grid3, cv=5, verbose=3, scoring="accuracy")

# %%
#grid_searchSVC.fit(X_train, y_train)

# %%
print("Best params", grid_searchSVC.best_params_)
print("Best score", grid_searchSVC.best_score_)
print("Best estimator", grid_searchSVC.best_estimator_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 print("Best params", grid_searchSVC.best_params_)
#       2 print("Best score", grid_searchSVC.best_score_)
#       3 print("Best estimator", grid_searchSVC.best_estimator_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
final_model3 = SVC(C=1, gamma=1,kernel="rbf", random_state=42, class_weight=None)

# %%
scores3 = cross_val_score(final_model3, X_train, y_train, cv=10, scoring="accuracy")

# %%
scores3.mean()
# Out:
# 0.9833134481992257

# %%
scores3
# Out:
# array([0.99516908, 0.98067633, 0.98792271, 0.97826087, 0.98550725,
#        0.98792271, 0.97820823, 0.97094431, 0.97820823, 0.99031477])

# %%
final_model3.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=1, random_state=42)

# %%
preds3 = final_model3.predict(X_test)

# %%
report3 = classification_report(y_test, preds3, output_dict=True)

# %%
report3
# Out:
# {'0': {'precision': 0.9986282578875172,
#   'recall': 0.9904761904761905,
#   'f1-score': 0.994535519125683,
#   'support': 735.0},
#  '1': {'precision': 0.9771241830065359,
#   'recall': 0.9966666666666667,
#   'f1-score': 0.9867986798679867,
#   'support': 300.0},
#  'accuracy': 0.9922705314009662,
#  'macro avg': {'precision': 0.9878762204470266,
#   'recall': 0.9935714285714285,
#   'f1-score': 0.990667099496835,
#   'support': 1035.0},
#  'weighted avg': {'precision': 0.9923951927046241,
#   'recall': 0.9922705314009662,
#   'f1-score': 0.992292957022003,
#   'support': 1035.0}}

# %%
params3 = final_model3.get_params()

# %%
params3
# Out:
# {'C': 1,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 1,
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': 42,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
mlflow.set_experiment("BOW TFIDFVECTORIZER SVC")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")
with mlflow.start_run():
    mlflow.log_params(params3)
    mlflow.log_metrics({
        "accuracy": report3["accuracy"],
        "recall_class_non_spam": report3["0"]["recall"],
        "precision_class_non_spam": report3["0"]["precision"],
        "f1_score_class_non_spam": report3["0"]["f1-score"],
        "recall_class_spam": report3["1"]["recall"],
        "precision_class_spam": report3["1"]["precision"],
        "f1_score_class_spam": report3["1"]["f1-score"],
    })

    mlflow.sklearn.log_model(
        final_model3,
        "model3",
        registered_model_name="BOW TFIDF SVC TEST"
    )
# Out:
# 2025/10/27 13:03:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/27 13:04:00 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Registered model 'BOW TFIDF SVC TEST' already exists. Creating a new version of this model...
# 2025/10/27 13:04:01 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: BOW TFIDF SVC TEST, version 3
# Created version '3' of model 'BOW TFIDF SVC TEST'.
# 🏃 View run honorable-fish-312 at: http://127.0.0.1:5000/#/experiments/481375677435585521/runs/4ceca828ffbb4ae1b9aee484ec496f20
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/481375677435585521

# %%
data.to_csv("versionMLData.csv", index=False)

# %%
mlflow.set_experiment("BOW TFIDFVECTORIZER SVC")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

with mlflow.start_run():
    mlflow.log_artifact("versionMLData.csv")
# Out:
# 🏃 View run secretive-wolf-212 at: http://127.0.0.1:5000/#/experiments/481375677435585521/runs/7d6edf5237614a98a4268f840e7f01bb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/481375677435585521

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
param_grid4 = {
    'alpha': [0.01, 0.1, 1, 2],
    'fit_prior': [True, False],
}

# %%
model4 = MultinomialNB()

# %%
grid_search_NB = GridSearchCV(model4, param_grid4, cv=5, verbose=3, scoring="accuracy")

# %%
grid_search_NB.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ........alpha=0.01, fit_prior=True;, score=0.970 total time=   0.0s
# [CV 2/5] END ........alpha=0.01, fit_prior=True;, score=0.967 total time=   0.0s
# [CV 3/5] END ........alpha=0.01, fit_prior=True;, score=0.967 total time=   0.0s
# [CV 4/5] END ........alpha=0.01, fit_prior=True;, score=0.956 total time=   0.0s
# [CV 5/5] END ........alpha=0.01, fit_prior=True;, score=0.966 total time=   0.0s
# [CV 1/5] END .......alpha=0.01, fit_prior=False;, score=0.963 total time=   0.0s
# [CV 2/5] END .......alpha=0.01, fit_prior=False;, score=0.956 total time=   0.0s
# [CV 3/5] END .......alpha=0.01, fit_prior=False;, score=0.967 total time=   0.0s
# [CV 4/5] END .......alpha=0.01, fit_prior=False;, score=0.953 total time=   0.0s
# [CV 5/5] END .......alpha=0.01, fit_prior=False;, score=0.963 total time=   0.0s
# [CV 1/5] END .........alpha=0.1, fit_prior=True;, score=0.965 total time=   0.0s
# ...

# %%
print("Best params", grid_search_NB.best_params_)
print("Best score", grid_search_NB.best_score_)
print("Best estimator", grid_search_NB.best_estimator_)
# Out:
# Best params {'alpha': 0.01, 'fit_prior': True}
# Best score 0.9654244723667993
# Best estimator MultinomialNB(alpha=0.01)

# %%
final_model4 = MultinomialNB(alpha=1, fit_prior=True)

# %%
score4 = cross_val_score(final_model4, X_train, y_train, cv=10, scoring="accuracy")

# %%
score4
# Out:
# array([0.97101449, 0.9589372 , 0.96376812, 0.96859903, 0.97584541,
#        0.95652174, 0.95399516, 0.94915254, 0.94673123, 0.97336562])

# %%
score4.mean()
# Out:
# 0.9617930542396275

# %%
final_model4.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1)

# %%
preds4 = final_model4.predict(X_test)

# %%
print(classification_report(y_test, preds4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       735
#            1       0.94      0.94      0.94       300
#
#     accuracy                           0.97      1035
#    macro avg       0.96      0.96      0.96      1035
# weighted avg       0.97      0.97      0.97      1035

# %%
report4 = classification_report(y_test, preds4, output_dict=True)

# %%
params4 = final_model4.get_params()

# %%
mlflow.set_experiment("Spam Detection TF-IDF Vectorizer Naive Bayes")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")
with mlflow.start_run():
    mlflow.log_params(params4)

    mlflow.log_metrics({
        "accuracy": report4["accuracy"],
        "recall_class_non_spam": report4["0"]["recall"],
        "precision_class_non_spam": report4["0"]["precision"],
        "f1_score_class_non_spam": report4["0"]["f1-score"],
        "recall_class_spam": report4["1"]["recall"],
        "precision_class_spam": report4["1"]["precision"],
        "f1_score_class_spam": report4["1"]["f1-score"],
    })

    mlflow.sklearn.log_model(final_model4,
                     'model4',
                     registered_model_name="Spam Detection Naive Bayes TF-IDF Vectorizer")
    mlflow.log_artifact("versionMLData.csv")
# Out:
# 2025/10/27 13:04:02 INFO mlflow.tracking.fluent: Experiment with name 'Spam Detection TF-IDF Vectorizer Naive Bayes' does not exist. Creating a new experiment.
# 2025/10/27 13:04:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/10/27 13:04:04 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Successfully registered model 'Spam Detection Naive Bayes TF-IDF Vectorizer'.
# 2025/10/27 13:04:05 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Spam Detection Naive Bayes TF-IDF Vectorizer, version 1
# Created version '1' of model 'Spam Detection Naive Bayes TF-IDF Vectorizer'.
# 🏃 View run skillful-mole-725 at: http://127.0.0.1:5000/#/experiments/351504102842052138/runs/537e2cf173f741bc9e233b65dff3e71d
# ...

# %%
import joblib

# %%
joblib.dump(final_model3, "SVCIterationModel.joblib")
# Out:
# ['SVCIterationModel.joblib']
